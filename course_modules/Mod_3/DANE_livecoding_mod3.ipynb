# %%
import numpy as np
import pandas as pd
import json

# %%
import requests

# %% [markdown]
# ### User-agent string:
#  some text that describes the system we are using to access the webpage. It is generally good etiquette to supply your user agent string a a "header" in a HTTP call

# %%
url = 'https://httpbin.org/user-agent'
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{\n  "user-agent": "python-requests/2.32.3"\n}\n'

# %% [markdown]
# ## The four key methods in the JSON package:
#     1. loads - convert a string in the python kernel to dictionaries/lists
#     2. load = load a text file and store it as dictionaries/lists
#     3. dumps = convert a dictionary/list in the python kernel to a text file
#     4. dump - save a dictionary/list in the python kernel to a text file

# %%
myjson = json.loads(r.text)
useragent = myjson['user-agent']
headers = {'User-agent': useragent}

# %% [markdown]
# ## Cocktail DB

# %%
url = 'http://www.thecocktaildb.com/api/json/v1/1/filter.php?c=Cocktail'
r = requests.get(url, headers = headers)

# %%
r
# Out:
# <Response [200]>

# %%
myjson = json.loads(r.text)
pd.json_normalize(myjson, record_path = ['drinks'])
# Out:
#                                strDrink  \
# 0                           155 Belmont
# 1   57 Chevy with a White License Plate
# 2                             747 Drink
# 3                           9 1/2 Weeks
# 4                   A Gilligan's Island
# ..                                  ...
# 95                           Miami Vice
# 96                            Michelada
# 97                        Midnight Mint
# 98                               Mojito
# 99                         Mojito Extra
#
#                                         strDrinkThumb idDrink
# 0   https://www.thecocktaildb.com/images/media/dri...   15346
# 1   https://www.thecocktaildb.com/images/media/dri...   14029
# 2   https://www.thecocktaildb.com/images/media/dri...  178318
# 3   https://www.thecocktaildb.com/images/media/dri...   16108
# 4   https://www.thecocktaildb.com/images/media/dri...   16943
# ..                                                ...     ...
# 95  https://www.thecocktaildb.com/images/media/dri...   13936
# 96  https://www.thecocktaildb.com/images/media/dri...  178343
# 97  https://www.thecocktaildb.com/images/media/dri...   14842
# 98  https://www.thecocktaildb.com/images/media/dri...   11000
# 99  https://www.thecocktaildb.com/images/media/dri...   15841
#
# [100 rows x 3 columns]

# %% [markdown]
# # Wikipedia

# %%
url = 'https://en.wikipedia.org/w/api.php?action=query&list=search&srsearch=Virginia&format=json&srlimit=500'
r = requests.get(url, headers = headers)
r
# Out:
# <Response [200]>

# %%
myjson = json.loads(r.text)

# %%
virginia_wiki_df = pd.json_normalize(myjson, record_path = ['query', 'search'])

# %% [markdown]
# # News API
#
#  fdb945a4af834f6998c92c65bea2c715
#
# Use a .env file to store API keys and bring them into Python privately

# %%
params = {'q': 'florida man', 'apiKey':  'fdb945a4af834f6998c92c65bea2c715'}
headers = {'User-Agent': useragent,
           'X-Api-Key':  'fdb945a4af834f6998c92c65bea2c715'}

# %%
url = 'https://newsapi.org/v2/everything'
r = requests.get(url, headers = headers, params = params)
myjson = json.loads(r.text)
news_df = pd.json_normalize(myjson, record_path = ['articles'])
myjson
# Out:
# {'status': 'ok',
#  'totalResults': 2688,
#  'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Steven Symes',
#    'title': 'Florida Man Thinks He’s Smarter Than Highway Patrol',
#    'description': 'Some people think they’re super sneaky and it shows when you watch enough police pursuit dashcam videos. But this one from Florida Highway Patrol really...',
#    'url': 'https://autos.yahoo.com/florida-man-think-smarter-highway-190000970.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/q5V8iv4z_efhfft0oQBmKQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/the_auto_wire_articles_747/8c8af5759ac0e20b5cdf71ec333e456e',
#    'publishedAt': '2024-06-09T17:30:00Z',
#    'content': 'Read the full story on The Auto Wire\r\nFlorida Man Thinks Hes Smarter Than Highway Patrol\r\nSome people think theyre super sneaky and it shows when you watch enough police pursuit dashcam videos. But t… [+1954 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': 'Florida Man Builds 10-Foot-Wide Tiny Home To Spite Neighbors, Then Lists It For $600,000',
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_eefe8e91-9ae4-4243-a981-deeab4841e33',
#    'urlToImage': None,
#    'publishedAt': '2024-06-10T12:30:16Z',
#    'content': "If you click 'Accept all', we and our partners, including 238 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': 'Florida man pleads not guilty to kidnapping his estranged wife from her apartment in Spain',
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_65394a48-891f-4680-a32e-a7f632d296b6',
#    'urlToImage': None,
#    'publishedAt': '2024-06-10T19:49:37Z',
#    'content': "If you click 'Accept all', we and our partners, including 238 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Jonathan Franklin',
#    'title': 'The Florida deputy who shot U.S. airman Roger Fortson has been fired',
#    'description': 'On Friday, the Okaloosa County, Fla., Sheriff’s Department said that Deputy Eddie Duran was fired following the completion of an administrative internal affairs investigation amid Fortson’s death.',
#    'url': 'https://www.npr.org/2024/05/31/g-s1-2326/roger-fortson-florida-deputy-shot-airman-fired',
#    'urlToImage': 'https://media.npr.org/assets/img/2024/05/16/forstson--14_wide-8a245c8918956ce24dc67b6cc3d0f48111497187.jpg?s=1400&c=100&f=jpeg',
#    'publishedAt': '2024-05-31T23:21:13Z',
#    'content': 'Chantemekki Fortson, mother of Roger Fortson, a U.S. Air Force senior airman, holds a photo of her son.\r\nMichael A. McCoy\r\nThe Florida deputy who shot and killed 23-year-old Roger Fortson in his home… [+3775 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': 'Man who fled California due to the ‘cost of living, politics, traffic and crime’ says he’s ‘much happier’ in Florida',
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_db6b7910-81bf-4cf1-bff5-5c71d03bb855',
#    'urlToImage': None,
#    'publishedAt': '2024-06-19T10:08:00Z',
#    'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': 'Associated Press',
#    'title': '3 Alabama Men Die After Becoming Distressed While Swimming at Florida Beach',
#    'description': 'Three Alabama men have died from likely drowning after becoming distressed while swimming at a Florida Panhandle beach.',
#    'url': 'https://time.com/6990914/alabama-men-deaths-distressed-swimming-florida-beach/',
#    'urlToImage': 'https://api.time.com/wp-content/uploads/2024/06/GettyImages-1351821465.jpg?quality=85&w=1024&h=628&crop=1',
#    'publishedAt': '2024-06-22T15:27:38Z',
#    'content': 'PANAMA CITY BEACH, Fla. Three Alabama men have died from likely drowning after becoming distressed while swimming at a Florida Panhandle beach, authorities said Saturday morning.\r\nThe young men had t… [+821 chars]'},
#   {'source': {'id': 'espn', 'name': 'ESPN'},
#    'author': None,
#    'title': 'Florida two-way star Caglianone keys MCWS win',
#    'description': 'Two-way star Jac Caglianone broke the Florida single-season home run record to help his team eliminate NC State and move on in the MCWS.',
#    'url': 'https://www.espn.com/espn/story/_/id/40372814/jac-caglianone-hits-record-hr-helps-florida-move-mcws',
#    'urlToImage': 'https://a3.espncdn.com/combiner/i?img=%2Fphoto%2F2024%2F0617%2Fr1347048_1024x576_16%2D9.jpg',
#    'publishedAt': '2024-06-17T22:24:36Z',
#    'content': 'Jun 17, 2024, 05:48 PM ET\r\nOMAHA, Neb. -- Two-way star Jac Caglianone broke the Florida single-season home run record to give his school the lead an inning after he struggled on the mound and got pul… [+2560 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Pilar Arias',
#    'title': 'Florida sniper shoots, kills bank robber holding hostages through computer monitor: Video',
#    'description': "Lee County Sheriff's Office in Florida shared video of one of its snipers in February firing through a computer monitor at an alleged bank robber who was...",
#    'url': 'https://www.yahoo.com/news/florida-sniper-shoots-kills-bank-115922800.html',
#    'urlToImage': 'https://media.zenfs.com/en/fox_news_text_979/f4e7a0636b48bf6c10c00822cc37df5f',
#    'publishedAt': '2024-06-10T11:59:22Z',
#    'content': "Video released by a Florida sheriff's office shows the moment a sniper shot through a computer monitor and killed a suspected armed bank robber who was holding hostages.\r\nIt all unfolded Feb. 6 at a … [+1724 chars]"},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Caitlin Tan',
#    'title': 'Display of a captured wolf in a Wyoming bar brings outrage',
#    'description': 'All of Wyoming is facing criticism after a man there displayed a wolf he captured in a bar.',
#    'url': 'https://www.npr.org/2024/05/28/nx-s1-4984051/wolf-display-wyoming-bar',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/964x542+0+277/resize/1400/quality/100/format/gif/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F0e%2F6f%2F145f1c5b4dbc9416ec430709aead%2F240528-cody-roberts-screengrab-3.gif',
#    'publishedAt': '2024-06-01T15:06:10Z',
#    'content': 'Wyoming is home to hundreds of wolves, most live in or near Yellowstone National Park. Theyre protected and a big tourist draw.\r\nBut elsewhere in the state wolves are still often reviled as predators… [+9994 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'The Associated Press',
#    'title': '3 Alabama men die after becoming distressed while swimming at Florida beach',
#    'description': 'Authorities say three Alabama men are dead from likely drowning after becoming distressed while swimming at a Florida Panhandle beach',
#    'url': 'https://abcnews.go.com/US/wireStory/3-alabama-men-die-after-becoming-distressed-swimming-111336929',
#    'urlToImage': 'https://s.abcnews.com/images/US/abc_news_default_2000x2000_update_16x9_992.jpg',
#    'publishedAt': '2024-06-22T14:45:58Z',
#    'content': 'PANAMA CITY BEACH, Fla. -- Three Alabama men have died from likely drowning after becoming distressed while swimming at a Florida Panhandle beach, authorities said Saturday morning.\r\nThe young men ha… [+824 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'ABC News',
#    'title': 'WATCH: Florida fugitive flees traffic stop, is rammed by police',
#    'description': 'Dramatic police chase footage shows the moment a Florida motorist with a warrant out for her arrest was rammed by pursuing officers on a major highway after she fled a traffic stop.',
#    'url': 'https://abcnews.go.com/US/video/florida-fugitive-flees-traffic-stop-rammed-police-110854932',
#    'urlToImage': 'https://i.abcnewsfe.com/a/946a61fb-8f88-4f55-8682-5e63232b2b01/240605_abc_social_florida_hpMain_16x9.jpg?w=992',
#    'publishedAt': '2024-06-05T11:58:47Z',
#    'content': "<ul><li>Whats next for Russia? \r\n</li><li>What comes next after Texas school shooting?\r\n</li><li>What's next for abortion rights in America?\r\n</li><li>The new battle for voting rights\r\n</li><li>How w… [+2284 chars]"},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'ABC News',
#    'title': 'WATCH: Florida braces for new round of dangerous flooding',
#    'description': 'Millions are under flood watches in South Florida as relentless extreme rain and possible life-threatening flooding soaks the area.',
#    'url': 'https://abcnews.go.com/GMA/News/video/florida-braces-new-round-dangerous-flooding-111117961',
#    'urlToImage': 'https://i.abcnewsfe.com/a/602a9de6-5e97-45c7-aaaf-48fbf38f3447/240614_gma_oquendo_flood5_hpMain_16x9.jpg?w=992',
#    'publishedAt': '2024-06-14T12:20:26Z',
#    'content': "<ul><li>Whats next for Russia? \r\n</li><li>What comes next after Texas school shooting?\r\n</li><li>What's next for abortion rights in America?\r\n</li><li>The new battle for voting rights\r\n</li><li>How w… [+2284 chars]"},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'ABC News',
#    'title': 'WATCH: 12-year-old wins 2024 Scripps National Spelling Bee',
#    'description': 'Bruhat Soma from Tampa, Florida, joins “GMA” after beating 244 other competitors to take the 2024 championship title.',
#    'url': 'https://abcnews.go.com/GMA/Living/video/12-year-wins-2024-scripps-national-spelling-bee-110706781',
#    'urlToImage': 'https://i.abcnewsfe.com/a/b5784f3c-c777-4b51-8f7d-ed9607d6a276/240531_gma_play_spellingbee3_hpMain_16x9.jpg?w=992',
#    'publishedAt': '2024-05-31T15:28:59Z',
#    'content': "<ul><li>Whats next for Russia? \r\n</li><li>What comes next after Texas school shooting?\r\n</li><li>What's next for abortion rights in America?\r\n</li><li>The new battle for voting rights\r\n</li><li>How w… [+2284 chars]"},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'ABC News',
#    'title': 'WATCH: Sea turtles interact in rare sighting off the coast of Florida',
#    'description': 'A pair of loggerhead turtles were spotted meeting up by a drone photographer off the coast of Florida.',
#    'url': 'https://abcnews.go.com/US/video/sea-turtles-interact-rare-sighting-off-coast-florida-110884486',
#    'urlToImage': 'https://i.abcnewsfe.com/a/d3754e3a-57c7-499e-9b55-0ea9c7977db8/240605_abc_social_TURTLES_hpMain_16x9.jpg?w=992',
#    'publishedAt': '2024-06-06T03:32:39Z',
#    'content': "<ul><li>Whats next for Russia? \r\n</li><li>What comes next after Texas school shooting?\r\n</li><li>What's next for abortion rights in America?\r\n</li><li>The new battle for voting rights\r\n</li><li>How w… [+2284 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Talia Lakritz',
#    'title': "Here's what every member of the Trump family is up to after leaving the White House",
#    'description': 'Donald Trump, who is running for president again in 2024, was found guilty on all 34 criminal counts in his hush-money trial involving Stormy Daniels.',
#    'url': 'https://www.businessinsider.com/trump-family-after-white-house-donald-melania-ivanka-2022-2',
#    'urlToImage': 'https://i.insider.com/64cd527c20f1cf0019cb038c?width=1200&format=jpeg',
#    'publishedAt': '2024-05-30T22:49:19Z',
#    'content': 'From left to right: Ivanka Trump, Eric Trump, Donald Trump Jr., and Tiffany Trump at the 2020 Republican National Convention.Jabin Botsford/The Washington Post via Getty Images\r\n<ul>\n<li>Donald Trump… [+10702 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Rebecca Rommen',
#    'title': 'Video that appears to show IDF soldier threatening mutiny in Gaza shared by son of Israeli PM Benjamin Netanyahu, say reports',
#    'description': '"Reservist soldiers do not intend to hand the keys over to any Palestinian authority," the  alleged reservist said in the video, per reports.',
#    'url': 'https://www.businessinsider.com/video-alleged-idf-soldier-threatening-gaza-mutiny-shared-netanyahus-son-2024-5',
#    'urlToImage': 'https://i.insider.com/657475197a3c8094d5db68f6?width=1200&format=jpeg',
#    'publishedAt': '2024-05-26T16:02:18Z',
#    'content': "IDF soldiers ground operation in Gaza.IDF\r\n<ul><li>Benjamin Netanyahu's son shared a video of an alleged masked reservist, reports said.</li><li>His speech appears to threaten a mutiny of IDF soldier… [+3143 chars]"},
#   {'source': {'id': None, 'name': 'TheInertia.com'},
#    'author': 'Cooper Gegan',
#    'title': 'Aggressive Shark Repeatedly Rams Florida Man’s Jet Ski',
#    'description': "A man's terrifying shark encounter in Walton County, Florida, occurred just days after a series of shark attacks have hit the region.",
#    'url': 'https://www.theinertia.com/news/aggressive-shark-repeatedly-rams-florida-mans-jet-ski/',
#    'urlToImage': 'https://media.zenfs.com/en/the_inertia_106/e850489e56dd4dbb764b0491e538e6a8',
#    'publishedAt': '2024-06-12T22:38:41Z',
#    'content': 'A Florida man was riding his jet ski when an aggressive shark began aggressively circling and even jumped out of the water to multiple times to ram the craft. The encounter occurred just days after a… [+2006 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'TERRY SPENCER Associated Press',
#    'title': 'Officers indicted for 2019 shootout with robbers that killed UPS driver and passerby',
#    'description': 'Four Florida police officers have been indicted for manslaughter in connection with a 2019 shootout on a busy rush-hour street that left a hijacked UPS driver and a passerby in a nearby car dead',
#    'url': 'https://abcnews.go.com/US/wireStory/4-florida-officers-indicted-2019-shootout-robbers-killed-111164002',
#    'urlToImage': 'https://i.abcnewsfe.com/a/beccf1ec-9b26-4147-9c08-68dc3874d546/wirestory_b2e6fd6f59a7cac1674b0ba725ff4d02_16x9.jpg?w=1600',
#    'publishedAt': '2024-06-16T12:14:01Z',
#    'content': 'FORT LAUDERDALE, Fla. -- Four Florida police officers have been indicted for manslaughter in connection with a 2019 shootout on a busy rush-hour street that left a hijacked UPS driver and a passerby … [+5722 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Chris Oberholtz',
#    'title': "See it: Catfish 'the size of a 6th grader' tops state record after pulled from Oklahoma reservoir",
#    'description': 'Have you ever encountered a catfish so massive that it rivals the size of your teenager on summer break from middle school?',
#    'url': 'https://www.yahoo.com/news/see-catfish-size-6th-grader-160955627.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/zYDkkREG6PTeEBwaLQ7gGQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/fox_weather_articles_483/5928e703cc6e3698460ac35c96dd99e9',
#    'publishedAt': '2024-05-30T16:09:55Z',
#    'content': 'VALLIANT, Okla. Have you ever encountered a catfish so massive that it rivals the size of your teenager on summer break from middle school?\r\n"Not to be too Oklahomish but do y\'all wanna see a catfish… [+1237 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Rebecca Hersher',
#    'title': 'Extreme heat contributed to his brother’s death. He worries he could be next',
#    'description': 'Wilmer Vasquez died at just 29 years old after suffering heat illness during the hottest year on record. His brother, Yonatan, says climate change played a big role.',
#    'url': 'https://www.npr.org/2024/06/23/nx-s1-4842309/extreme-heat-climate-remembrance-vasquez',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/1024x576+0+0/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fa3%2F43%2F5cfe4f1e48e8be35ddcebc455429%2Fb8173ef6-0c4d-44be-9a69-3e2a0d71c4d6.jpg',
#    'publishedAt': '2024-06-23T10:00:00Z',
#    'content': 'Ever since they were little, Yonatan Vasquez was best friends with his brother Wilmer.\r\nIt wasnt that they were so similar. Wilmer, the younger one, was an extrovert. He just wanted to be around peop… [+6186 chars]'},
#   {'source': {'id': None, 'name': 'Jalopnik'},
#    'author': 'Owen Bellwood',
#    'title': 'Passenger Dies After Falling Overboard From World’s Largest Cruise Ship',
#    'description': 'A man died after falling from the deck on the world’s largest cruise ship, Icon of the Seas last week. The massive vessel had just started a seven-night cruise from Miami, Florida, when the man fell from one of its 20 decks, sparking a two-hour rescue mission…',
#    'url': 'https://jalopnik.com/passenger-dies-after-falling-overboard-from-world-s-lar-1851503273',
#    'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/8fa443d2d3baf82103771a1a3e50d37b.jpg',
#    'publishedAt': '2024-05-28T14:55:00Z',
#    'content': 'A man died after falling from the deck on the worlds largest cruise ship, Icon of the Seas last week. The massive vessel had just started a seven-night cruise from Miami, Florida, when the man fell f… [+2183 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': "'I’m One Tap Away From Publishing Your Nudes': 12 Horror Stories About Extortion Attempts on Grindr",
#    'description': 'Technology has pushed the world of dating into our phones, those same devices that allow us to take photos and videos we may not want the rest of the world to see. And that tectonic shift in culture has made it much easier to run anonymous extortion scams, wh…',
#    'url': 'https://gizmodo.com/grindr-extortion-ftc-foia-horror-stories-lgbtq-dating-1851526931',
#    'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/df5ae0df006df19abe5d9eed6d817476.jpg',
#    'publishedAt': '2024-06-13T16:10:00Z',
#    'content': 'Technology has pushed the world of dating into our phones, those same devices that allow us to take photos and videos we may not want the rest of the world to see. And that tectonic shift in culture … [+14348 chars]'},
#   {'source': {'id': None, 'name': 'Pitchfork'},
#    'author': 'Nina Corcoran',
#    'title': '2 Live Crew Rapper Brother Marquis Dies at 58',
#    'description': 'The Miami, Florida hip-hop group courted controversy in the ’80s and ’90s with raunchy lyrics',
#    'url': 'https://pitchfork.com/news/2-live-crew-rapper-brother-marquis-dies-at-58/',
#    'urlToImage': 'https://media.pitchfork.com/photos/665e44075661aab72998534b/16:9/w_1280,c_limit/GettyImages-101621125.jpg',
#    'publishedAt': '2024-06-03T23:38:03Z',
#    'content': 'Mark D. Ross, best known as the rapper Brother Marquis in 2 Live Crew, has died, according to a social media post by the group and TMZ confirms. Mark Ross AKA Brother Marquis of the 2 Live crew has w… [+2027 chars]'},
#   {'source': {'id': 'espn', 'name': 'ESPN'},
#    'author': 'Andreas Hale',
#    'title': "With Tyson out, Paul to fight Bare Knuckle's Perry",
#    'description': 'Jake Paul will not wait for Nov. 15 to get back into a boxing ring, instead he will fight Bare Knuckle Fighting Championship\'s "Platinum" Mike Perry on July 20.',
#    'url': 'https://www.espn.com/boxing/story/_/id/40378326/jake-paul-fight-mike-perry-original-mike-tyson-date',
#    'urlToImage': 'https://a3.espncdn.com/combiner/i?img=%2Fphoto%2F2023%2F1108%2Fr1250409_1296x729_16%2D9.jpg',
#    'publishedAt': '2024-06-18T16:07:40Z',
#    'content': 'Jake Paul will not wait for Nov. 15 to get back into a boxing ring. Paul has decided to keep the date that was slated for the blockbuster showdown with legendary heavyweight Mike Tyson and will inste… [+4888 chars]'},
#   {'source': {'id': 'espn', 'name': 'ESPN'},
#    'author': None,
#    'title': "WR Dell on shooting: 'Wrong place, wrong time'",
#    'description': 'Texans wide receiver Tank Dell, appearing on the "Million Dollaz Worth of Game" podcast, discussed publicly for the first time the night he was shot in April.',
#    'url': 'https://www.espn.com/nfl/story/_/id/40275390/texans-tank-dell-discusses-night-was-shot-first',
#    'urlToImage': 'https://a2.espncdn.com/combiner/i?img=%2Fphoto%2F2024%2F0604%2Fr1341479_2_1296x729_16%2D9.jpg',
#    'publishedAt': '2024-06-04T13:58:11Z',
#    'content': 'Houston Texans wide receiver Tank Dell discussed publicly for the first time the night he was shot in April and said it was a matter of being in the wrong place at the wrong time.\r\nDell made his comm… [+2813 chars]'},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': 'Associated Press and TIME Staff',
#    'title': 'Lifeguard Dies After Being Attacked by Shark While Surfing in Hawaii',
#    'description': 'Shark attacks are rare, and fatalities are even less common.',
#    'url': 'https://time.com/6991099/hawaii-oahu-lifeguard-dies-shark-attack-surfing/',
#    'urlToImage': 'https://api.time.com/wp-content/uploads/2024/06/Shark-Attack-Warning-Hawaii.jpg?quality=85&crop=0px%2C273px%2C1999px%2C1047px&resize=1200%2C628&strip',
#    'publishedAt': '2024-06-24T07:33:00Z',
#    'content': 'A professional lifeguard died after he was attacked by a shark while surfing off the island of Oahu in Hawaii on Sunday afternoon, authorities said.\r\nCity and County of Honolulu Ocean Safety lifeguar… [+2210 chars]'},
#   {'source': {'id': None, 'name': 'Quartz India'},
#    'author': 'Owen Bellwood / Jalopnik',
#    'title': 'A passenger fell off the world’s biggest cruise ship and died',
#    'description': 'A man died after falling from the deck on the world’s largest cruise ship, Icon of the Seas last week. The massive vessel had just started a seven-night cruise from Miami, Florida, when the man fell from one of its 20 decks, sparking a two-hour rescue mission…',
#    'url': 'https://qz.com/royal-caribbean-icon-of-the-seas-passenger-falls-dies-1851504339',
#    'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/8fa443d2d3baf82103771a1a3e50d37b.jpg',
#    'publishedAt': '2024-05-28T17:49:02Z',
#    'content': 'A man died after falling from the deck on the worlds largest cruise ship, Icon of the Seas last week. The massive vessel had just started a seven-night cruise from Miami, Florida, when the man fell f… [+2244 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Stephen Silver)',
#    'title': 'Crime blotter: California Apple Store theft suspects in court',
#    'description': "In this week's roundup of Apple-related crime, a Man who burned down home over iPhone misunderstanding gets prison, iPhone scammers get arrested, and a man tracks his stolen AirPods Pro to Iraq.The Bluewater Apple Store in the UK The video of a thief ransacki…",
#    'url': 'https://appleinsider.com/articles/24/06/02/crime-blotter-california-apple-store-theft-suspects-in-court',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/59791-122256-bluewater-xl.jpg',
#    'publishedAt': '2024-06-02T23:00:34Z',
#    'content': "The Bluewater Apple Store in the UK \r\nIn this week's roundup of Apple-related crime, a Man who burned down home over iPhone misunderstanding gets prison, iPhone scammers get arrested, and a man track… [+5010 chars]"},
#   {'source': {'id': None, 'name': 'TMZ'},
#    'author': 'TMZ Staff',
#    'title': 'Florida Sniper Shoots Bank Robber Through Computer, Rescues Hostages',
#    'description': "New footage from a bank robbery earlier this year shows just how delicate the situation was ... with one police sniper taking a seemingly impossible shot to rescue hostages. Officers for the Lee County Sheriff's Department surrounded a Fort Myers…",
#    'url': 'https://www.tmz.com/2024/06/10/florida-sniper-shoots-bank-robber-hostage-through-computer/',
#    'urlToImage': 'https://imagez.tmz.com/image/f9/16by9/2024/06/10/f9fce5f801bd4e47b8063f1ece89b972_xl.jpg',
#    'publishedAt': '2024-06-10T14:51:24Z',
#    'content': 'New footage from a bank robbery earlier this year shows just how delicate the situation was ... with one police sniper taking a seemingly impossible shot to rescue hostages.\r\nOfficers for the Lee Cou… [+1631 chars]'},
#   {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#    'author': 'Scott Polacek',
#    'title': "Panthers Win Game 2 vs. McDavid, Oilers as NHL Fans Hype Evan Rodrigues' Late Goals",
#    'description': "The Florida Panthers are two wins away from their first Stanley Cup title in franchise history. Florida defeated the Edmonton Oilers 4-1 in Monday's Game 2 of…",
#    'url': 'https://bleacherreport.com/articles/10124320-panthers-win-game-2-vs-mcdavid-oilers-as-nhl-fans-hype-evan-rodrigues-late-goals',
#    'urlToImage': 'https://media.bleacherreport.com/image/upload/c_fill,g_faces,w_3800,h_2000,q_95/v1718075274/eqa4em8okvg7gpdrs0jo.jpg',
#    'publishedAt': '2024-06-11T03:18:20Z',
#    'content': "Bruce Bennett/Getty Images\r\nThe Florida Panthers are two wins away from their first Stanley Cup title in franchise history.\r\nFlorida defeated the Edmonton Oilers 4-1 in Monday's Game 2 of the Stanley… [+4500 chars]"},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Joe Hernandez',
#    'title': 'A Florida family is suing NASA after a piece of space debris crashed through their home',
#    'description': 'The space agency determined that the material was a metal alloy stanchion used on “NASA flight support equipment.”',
#    'url': 'https://www.npr.org/2024/06/23/nx-s1-5016923/space-debris-nasa-florida-home-lawsuit',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/5568x3132+0+227/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fca%2F6a%2Fe38402704725bfc9485c77cf9764%2Fiss064e041512-orig.jpg',
#    'publishedAt': '2024-06-23T16:35:54Z',
#    'content': 'A Florida family is suing NASA after a piece of metallic space debris belonging to the agency fell to Earth and tore through their Naples home earlier this year, leaving a hole in the roof.\r\nThe Marc… [+2099 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Joe Allen',
#    'title': '5 great Netflix movies to watch on Juneteenth',
#    'description': 'These five movies on Netflix are the perfect way to reflect and celebrate on Juneteenth.',
#    'url': 'https://www.digitaltrends.com/movies/great-netflix-movies-watch-juneteenth-2024/',
#    'urlToImage': 'https://www.digitaltrends.com/wp-content/uploads/2021/11/the-harder-they-fall-jonathan-majors-idris-elba.jpg?resize=1200%2C630&p=1',
#    'publishedAt': '2024-06-19T13:15:58Z',
#    'content': 'Netflix\r\nAlthough it only recently became a federal holiday, Juneteenth feels a little bit like a second Independence Day. It’s a day when America celebrates the end of enslavement, and reflects on a… [+3641 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'Bethany Braun-Silva, Zohreen Shah',
#    'title': '19-year-old speaks out after surviving shark attack in Texas',
#    'description': 'Damiana Humphrey, 19, said she punched the shark until she was free.',
#    'url': 'https://abcnews.go.com/GMA/News/19-year-speaks-after-surviving-shark-attack-texas/story?id=110954406',
#    'urlToImage': 'https://i.abcnewsfe.com/a/583a8055-c85a-4f6f-8038-b1748cf82ddc/galveston-island-beach-gty-jt-240608_1717869762255_hpMain_16x9.jpg?w=1600',
#    'publishedAt': '2024-06-08T20:51:00Z',
#    'content': 'An Oklahoma teen and her family are speaking out after the 19-year-old was attacked by a shark last month in Galveston, Texas.\r\nDamiana Humphrey, 19, told "Good Morning America" she was wading in the… [+1815 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'Isabella Murray, Josh Margolin',
#    'title': 'Oklahoma voters to decide between GOP incumbent Tom Cole, challenger Paul Bondar',
#    'description': "Cole's opponent Paul Bondar reportedly has ties to a Russian pop star linked to Putin, leaving some wondering if Cole is being targeted over of his support for Ukraine.",
#    'url': 'https://abcnews.go.com/Politics/oklahoma-voters-decide-gop-incumbent-tom-cole-funded/story?id=111183528',
#    'urlToImage': 'https://i.abcnewsfe.com/a/37aa8062-6a0d-49d5-9c7f-345e7402a72b/tom-cole-gty-jef-240617_1718636066934_hpMain_16x9.jpg?w=1600',
#    'publishedAt': '2024-06-18T00:02:43Z',
#    'content': 'On Tuesday in Oklahoma, Republican Rep. Tom Cole, chair of the powerful House Appropriations Committee, will face one of his most significant and costly primary challenges since he went to Congress 2… [+8412 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Rachel Treisman',
#    'title': 'Heat and snowfall, rain and wildfires. It’s a week of extreme weather in the U.S',
#    'description': 'As New England sweated through a record heat wave, Montana got rare late-June snow. Firefighters are battling wildfires out West, while forecasters eye another possible tropical storm in the Atlantic.',
#    'url': 'https://www.npr.org/2024/06/20/nx-s1-5013299/us-extreme-weather-heat-wave-wildfires-tropical-storm-alberto',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/8067x4538+0+420/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F30%2Ff1%2Ff33ba6ee4802a6a9053708fd7ad9%2Fgettyimages-2158434753.jpg',
#    'publishedAt': '2024-06-20T20:40:54Z',
#    'content': 'The U.S. is experiencing a number of extreme and varied weather events at once, from the prolonged heat wave scorching the Northeast to the deadly wildfires blazing in New Mexico to the tropical stor… [+7092 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Majd Al-Waheidi',
#    'title': 'Two years after Dobbs; militants attack in southern Russia',
#    'description': "Deadly attacks reported in Russia's southern republic of Dagestan. Abortions are up two years since the Supreme Court revoked federal abortion protections.",
#    'url': 'https://www.npr.org/2024/06/24/g-s1-5876/up-first-newsletter-two-years-after-dobbs-militants-attack-in-russia',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/600x338+0+75/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fb5%2F2f%2F4c942cd14ef49d1adba6e513ba03%2Fgettyimages-2107842325-ad4d3e551624450ee470100a0c1551ff0b051d87.jpg',
#    'publishedAt': '2024-06-24T12:28:47Z',
#    'content': "Today's top stories\r\nTwo years ago today, the Supreme Court overturned Roe v. Wade, removing federal protections for abortion. The Dobbs decision allowed states to ban and restrict abortion, signific… [+6335 chars]"},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': 'Bruce Schreiner and Julio Cortez / AP',
#    'title': 'At Least 22 Dead After Memorial Day Weekend Storms Sweep Through Several States',
#    'description': 'A series of powerful storms swept over the central and southern U.S. over the Memorial Day holiday weekend, causing deaths in Texas, Oklahoma, Arkansas and Kentucky.',
#    'url': 'https://time.com/6982530/memorial-day-storms/',
#    'urlToImage': 'https://api.time.com/wp-content/uploads/2024/05/texas-truck-stop-memorial-day-storm.jpg?quality=85&w=1024&h=576&crop=1',
#    'publishedAt': '2024-05-28T01:15:00Z',
#    'content': 'A series of powerful storms swept over the central and southern U.S. over the Memorial Day holiday weekend, killing at least 22 people and leaving a wide trail of destroyed homes, businesses and powe… [+4444 chars]'},
#   {'source': {'id': None, 'name': 'Daytona Beach News-Journal'},
#    'author': 'Frank Fernandez, Daytona Beach News-Journal',
#    'title': "Volusia, Flagler sheriffs' offices face lawsuits over chase that killed innocent siblings",
#    'description': 'The chase began in Flagler County and ended when the fleeing man drove a stolen car the wrong way on I-95, crashing into an SUV and killing two inside.',
#    'url': 'https://www.news-journalonline.com/story/news/courts/2024/06/13/volusia-flagler-sheriffs-offices-sued-for-chase-that-killed-siblings/74072719007/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/8jxn0rRN9t4chBV7.9.JLA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MzM-/https://media.zenfs.com/en/daytona-beach-news-journal/669cdcb7654d9660dc4d332ffab8bac7',
#    'publishedAt': '2024-06-13T17:01:15Z',
#    'content': "Volusia and Flagler county sheriffs' deputies are accused of negligence and carelessness in a high-speed pursuit of a stolen car whose fleeing driver drove the wrong way on Interstate-95 and crashed … [+8380 chars]"},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'newsweek.com',
#    'title': 'Alligator Attacks Man Swimming in Florida Lake',
#    'description': "A man in central Florida was left with an amputated arm after an alligator attacked him in Lake Monroe early Sunday morning.\nAccording to local reports, officials with the state's Fish and Wildlife Commission (FWC) said that the man, who was reportedly homele…",
#    'url': 'https://biztoc.com/x/f269cd3c56a0e169',
#    'urlToImage': 'https://biztoc.com/cdn/f269cd3c56a0e169_s.webp',
#    'publishedAt': '2024-06-18T22:49:50Z',
#    'content': "A man in central Florida was left with an amputated arm after an alligator attacked him in Lake Monroe early Sunday morning.According to local reports, officials with the state's Fish and Wildlife Co… [+136 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Joi-Marie McKenzie',
#    'title': 'Insider Today: Travel agents are back',
#    'description': "In Saturday's edition of Insider Today, we're talking about the rise of travel agents.",
#    'url': 'https://www.businessinsider.com/insider-today-saturday-travel-agents-return-food-for-healthy-brain',
#    'urlToImage': 'https://i.insider.com/666ae93ded9a404d829d4698?width=1200&format=jpeg',
#    'publishedAt': '2024-06-16T11:17:01Z',
#    'content': "Edmon de Haro for BI\r\n<ul><li>This post originally appeared in the Insider Today newsletter.</li><li>You can sign up for Business Insider's daily newsletter here.</li></ul>Happy Saturday! After decid… [+5451 chars]"},
#   {'source': {'id': None, 'name': 'Faz.net'},
#    'author': 'sid/dpa/gif.',
#    'title': 'Draisaitl verliert mit den Oilers auch das dritte NHL-Finalspiel',
#    'description': 'Der deutsche Eishockey-Star bleibt bei der 3:4-Niederlage der Edmonton Oilers gegen die Florida Panthers abermals ohne Scorerpunkt: Bereits in der Nacht zu Sonntag droht die endgültige Entscheidung.',
#    'url': 'https://www.faz.net/aktuell/sport/mehr-sport/stanley-cup-leon-draisaitl-verliert-mit-oilers-auch-drittes-nhl-finalspiel-19788066.html',
#    'urlToImage': 'https://media0.faz.net/ppmedia/aktuell/sport/440741864/1.9788074/facebook_teaser/skeptischer-blick-fuer-leon.jpg',
#    'publishedAt': '2024-06-14T06:05:16Z',
#    'content': 'Bereits in der Nacht zu Sonntag (MEZ) im zweiten Heimspiel der Oilers könnte sich Vorjahresfinalist Florida zum ersten Mal den Titel sichern. Draisaitl blieb auch im dritten Spiel der Finalserie ohne… [+2103 chars]'},
#   {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#    'author': 'Scott Polacek',
#    'title': "Rory McIlroy, Wife Erica Call Off Divorce: Our 'Best Future' Is as a Family Together",
#    'description': 'Rory McIlroy will pursue the U.S. Open title this weekend as a married man. Ewan Murray of The Guardian reported Tuesday that the golf star and his wife,…',
#    'url': 'https://bleacherreport.com/articles/10124450-rory-mcilroy-wife-erica-call-off-divorce-our-best-future-is-as-a-family-together',
#    'urlToImage': 'https://media.bleacherreport.com/image/upload/c_fill,g_faces,w_3800,h_2000,q_95/v1718147110/hpd4mh1jkdxuzpwygnfx.jpg',
#    'publishedAt': '2024-06-11T23:18:02Z',
#    'content': 'Sean M. Haffey/Getty Images\r\nRory McIlroy will pursue the U.S. Open title this weekend as a married man.\r\nEwan Murray of The Guardian reported Tuesday that the golf star and his wife, Erica Stoll, de… [+2005 chars]'},
#   {'source': {'id': None, 'name': 'Techdirt'},
#    'author': 'Tim Cushing',
#    'title': 'Florida Sheriff Grady Judd Decides He’s Capable Of Running An AI Crime Thingy',
#    'description': 'Sheriffs answer to no one but voters. Consequently, they often answer to no one. Voters tend to gravitate towards names they recognize. Sheriffs count on this form of “loyalty” to ensure years or decades at the helm of a county law enforcement agency. And thi…',
#    'url': 'https://www.techdirt.com/2024/06/17/florida-sheriff-grady-judd-decides-hes-capable-of-running-an-ai-crime-thingy/',
#    'urlToImage': 'https://www.techdirt.com/wp-content/themes/techdirt/assets/images/td-rect-logo-white.png',
#    'publishedAt': '2024-06-17T16:20:00Z',
#    'content': "from the never-met-a-varmint-he-cain't-round-up dept\r\nSheriffs answer to no one but voters. Consequently, they often answer to no one. \r\nVoters tend to gravitate towards names they recognize. Sheriff… [+6307 chars]"},
#   {'source': {'id': None, 'name': 'heise online'},
#    'author': 'Martin Holland',
#    'title': 'Studie zu den USA: Ältere Frauen verbreiten besonders viel Desinformation',
#    'description': 'Eine Analyse von 660.000 Accounts auf X bestätigt, dass extrem wenige Accounts die meisten Fake News verbreiten. Sie zeigt nun auch, um wen es sich handelt.',
#    'url': 'https://www.heise.de/news/Studie-zu-den-USA-Aeltere-Frauen-verbreiten-besonders-viel-Desinformation-9742674.html',
#    'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/6/0/3/0/1/4/shutterstock_2223747151-2bfb1e2236582589.jpg',
#    'publishedAt': '2024-05-31T06:38:00Z',
#    'content': 'In den USA verbreiten deutlich weniger als ein Prozent der User des Kurznachrichtendiensts X (vormals Twitter) dort den Großteil von Desinformation, dabei handelt es sich überproportional um ältere W… [+3078 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Dani Medina',
#    'title': 'Deadly Winter Springs carjacking suspects set woman ablaze after carjacking her for $170K: new federal docs',
#    'description': 'New details have been released about the carjacking and death of 31-year-old Katherine Altagracia Guerrero De Aguasvivas, including a timeline of what...',
#    'url': 'https://www.yahoo.com/news/deadly-winter-springs-carjacking-suspects-232602558.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/mlnJW60ldm0m7CZUVuryzQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/wofl_fox_local_articles_124/95a0153bc48a91f39fa5a16ab591b59d',
#    'publishedAt': '2024-06-06T23:26:02Z',
#    'content': 'SEMINOLE COUNTY, Fla. - FOX 35 has obtained new federal documents that detail what happened to Katherine Altagracia Guerrero De Aguasvivas on the day of her death.\r\nThe 31-year-old was carjacked at g… [+2845 chars]'},
#   {'source': {'id': None, 'name': 'Rolling Stone'},
#    'author': 'Daniel Kreps',
#    'title': 'Arizona Man Indicted After Planning Mass Shooting at Atlanta Concert to Incite Race War',
#    'description': 'Mark Adams Prieto faces federal weapons charges after a sting operation where he devised a plan "to commit a mass shooting of African Americans and other minorities" by targeting a Bad Bunny show',
#    'url': 'http://www.rollingstone.com/culture/culture-news/arizona-man-indicted-planned-mass-shooting-atlanta-concert-incite-race-war-1235038613/',
#    'urlToImage': 'https://www.rollingstone.com/wp-content/uploads/2024/06/GettyImages-1125231368.jpg?w=1600&h=900&crop=1',
#    'publishedAt': '2024-06-12T16:48:23Z',
#    'content': 'An Arizona man was indicted on federal weapons charges after being arrested as part of a sting operation that involved a planned hate crime-related mass shooting at an Atlanta concert.\r\nMark Adams Pr… [+2320 chars]'},
#   {'source': {'id': None, 'name': 'Fast Company'},
#    'author': 'Associated Press',
#    'title': 'AI chatbots just can’t shake off gender stereotypes, here’s why',
#    'description': 'Many, whether they realize it or not, will gravitate toward a female chatbot voice because it’s perceived as less threatening than a male voice. \n\nWhen disinformation researcher Wen-Ping Liu looked into China’s efforts to influence Taiwan’s recent election us…',
#    'url': 'https://www.fastcompany.com/91139842/ai-chatbots-just-cant-shake-off-gender-stereotypes-heres-why',
#    'urlToImage': 'https://images.fastcompany.com/image/upload/f_auto,q_auto,c_fit/wp-cms-2/2024/06/AP24162711414173.jpg',
#    'publishedAt': '2024-06-12T12:48:38Z',
#    'content': 'When disinformation researcher Wen-Ping Liu looked into Chinas efforts to influence Taiwans recent election using fake social media accounts, something unusual stood out about the most successful pro… [+5025 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Brent D. Griffiths',
#    'title': "What Mitch McConnell's truce with Trump means",
#    'description': 'Mitch McConnell praised Trump\'s "really positive" meeting with Senate Republicans.',
#    'url': 'https://www.businessinsider.com/mitch-mcconnell-trump-relationship-now-endorsement-senate-gop-2024-6',
#    'urlToImage': 'https://i.insider.com/666c5927e079049018191c66?width=1200&format=jpeg',
#    'publishedAt': '2024-06-15T12:06:02Z',
#    'content': 'Former President Donald Trump and Senate Minority Leader Mitch McConnell (seen here in 2019) have had a complicated relationship.Bryan Woolston/Getty Images\r\n<ul><li>Donald Trump shook Sen. Mitch McC… [+6679 chars]'},
#   {'source': {'id': None, 'name': 'TMZ'},
#    'author': 'TMZ Staff',
#    'title': 'Giant Venomous Flying Spiders Invading New York, Spreading Up East Coast',
#    'description': "Peter Parker's got company ... an invasive species of spider is preparing to invade New York, and these arachnids can fly through the air like Spider-Man!  Folks in New York and New Jersey are bracing for the imminent arrival of the Joro…",
#    'url': 'https://www.tmz.com/2024/06/04/giant-venomous-flying-spiders-invading-new-york-joro/',
#    'urlToImage': 'https://imagez.tmz.com/image/9e/16by9/2024/06/04/9e03d6743ad347109a72796027087638_xl.jpg',
#    'publishedAt': '2024-06-04T20:22:16Z',
#    'content': "Peter Parker's got company ... an invasive species of spider is preparing to invade New York, and these arachnids can fly through the air like Spider-Man! \r\nFolks in New York and New Jersey are braci… [+1502 chars]"},
#   {'source': {'id': None, 'name': 'Theonion.com'},
#    'author': 'ji39f8deollek3',
#    'title': 'New Florida Law Allows C-Sections To Be Performed By Any Machete-Wielding Lunatic',
#    'description': 'TALLAHASSEE, FL—Claiming the move would empower women to take control of their bodies, the Florida Legislature passed a new law Friday that allows cesarean sections to be performed by any machete-wielding lunatic. “Starting today, women in Florida will no lon…',
#    'url': 'https://www.theonion.com/new-florida-law-allows-c-sections-to-be-performed-by-an-1851546261',
#    'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/3ef3bd0112190c0b6a02069cf1d34034.jpg',
#    'publishedAt': '2024-06-21T10:15:00Z',
#    'content': 'TALLAHASSEE, FLClaiming the move would empower women to take control of their bodies, the Florida Legislature passed a new law Friday that allows cesarean sections to be performed by any machete-wiel… [+974 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'JOHN RABY',
#    'title': 'Accused lookout in James “Whitey” Bulger prison killing pleads guilty, gets no additional time',
#    'description': 'Sean McKinnon, wearing shackles, was hugged by both of his attorneys after U.S. District Judge Thomas Kleeh agreed with prosecutors’ recommendation that he...',
#    'url': 'https://www.yahoo.com/news/3-men-set-pleas-sentencings-040456972.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/ALj6sbEiNwYF.bavbwus8w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04NDQ-/https://media.zenfs.com/en/ap.org/d65914eb56e3bc51609d113da1fe37c6',
#    'publishedAt': '2024-06-17T04:04:56Z',
#    'content': 'CLARKSBURG, W.Va. (AP) The man accused of acting as lookout during the prison killing of notorious Boston gangster James Whitey Bulger wont serve additional prison time after pleading guilty Monday t… [+4597 chars]'},
#   {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#    'author': 'Paul Kasabian',
#    'title': "Rangers Take 2-1 Series Lead vs. Panthers as NHL Fans Praise Wennberg's G3 OT Goal",
#    'description': "Alex Wennberg's overtime goal propelled the New York Rangers to a 5-4 win over the Florida Panthers on Sunday, giving the Blueshirts a 2-1 lead in the…",
#    'url': 'https://bleacherreport.com/articles/10122632-rangers-take-2-1-series-lead-vs-panthers-as-nhl-fans-praise-wennbergs-g3-ot-goal',
#    'urlToImage': 'https://media.bleacherreport.com/image/upload/c_fill,g_faces,w_3800,h_2000,q_95/v1716763825/zrru9zzrlet0uhmcvtw9.jpg',
#    'publishedAt': '2024-05-26T23:15:28Z',
#    'content': "Bruce Bennett/Getty Images\r\nAlex Wennberg's overtime goal propelled the New York Rangers to a 5-4 win over the Florida Panthers on Sunday, giving the Blueshirts a 2-1 lead in the best-of-seven Easter… [+10053 chars]"},
#   {'source': {'id': None, 'name': 'Fark.com'},
#    'author': None,
#    'title': 'Florida man arrested over surprise furniture donation in NYC [Florida]',
#    'description': '<table> <tr><td> </td><td> [link] [2 comments] </td></tr></table>',
#    'url': 'https://www.fark.com/comments/13297724/Florida-man-arrested-over-surprise-furniture-donation-in-NYC',
#    'urlToImage': 'https://usrimg-850.fark.net/2/2p/fark_2pYdXH2_Z98YZUOlNgNtddR7E-s.jpg?AWSAccessKeyId=JO3ELGV4BGLFW7Y3EZXN&Expires=1719201600&Signature=ArzyueQHAdpZYf3gm8Uiu0HPEsQ%3D',
#    'publishedAt': '2024-06-23T02:41:09Z',
#    'content': '<li>Links are submitted by members of the Fark community.\r\n</li><li>When community members submit a link, they also write a custom headline for the story.\r\n</li><li>Other Farkers comment on the links… [+177 chars]'},
#   {'source': {'id': None, 'name': '/FILM'},
#    'author': 'staff@slashfilm.com (Bill Bria)',
#    'title': 'A Director Cameo Unites The Bad Boys Sequels – And It Demands A Proper Investigation',
#    'description': "We investigate a certain director cameo that's been happening in the Bad Boys movies, including Bad Boys: Ride or Die.",
#    'url': 'https://www.slashfilm.com/1596443/bad-boys-ride-or-die-michael-bay-cameo/',
#    'urlToImage': 'https://www.slashfilm.com/img/gallery/a-director-cameo-unites-the-bad-boys-sequels-and-it-demands-a-proper-investigation/l-intro-1717769107.jpg',
#    'publishedAt': '2024-06-07T14:00:00Z',
#    'content': 'Not so fast, buddy. Sometimes a cameo is just a cameo, but in this instance to borrow a phrase from another Bay franchise there may be more than meets the eye. Sure, it may seem unlikely at first blu… [+1462 chars]'},
#   {'source': {'id': None, 'name': 'Fark.com'},
#    'author': None,
#    'title': 'Florida Man: "Man, I\'m gonna go to the grocery store and start cooking" [Florida]',
#    'description': 'Florida Man: "Man, I\'m gonna go to the grocery store and start cooking"',
#    'url': 'https://www.fark.com/comments/13271484/Florida-Man-Man-Im-gonna-go-to-grocery-store-start-cooking',
#    'urlToImage': 'https://usrimg-850.fark.net/Z/Zb/fark_Zb5xlioPI1FHEbfeJTViGsAKg5U.jpg?AWSAccessKeyId=JO3ELGV4BGLFW7Y3EZXN&Expires=1717387200&Signature=YltXDnZqlFrn91y079h0v%2FUT2rI%3D',
#    'publishedAt': '2024-05-30T20:44:10Z',
#    'content': '<li>Links are submitted by members of the Fark community.\r\n</li><li>When community members submit a link, they also write a custom headline for the story.\r\n</li><li>Other Farkers comment on the links… [+177 chars]'},
#   {'source': {'id': None, 'name': 'Fci Academy'},
# ...
#    'url': 'https://www.fark.com/comments/13299108/Groom-to-be-catches-massive-hammerhead-shark-during-bachelor-party-in-Florida-Cool-tag-steps-in-as-best-man',
#    'urlToImage': 'https://usrimg-full.fark.net/t/te/fark_teCc8GW8Em0ofzw71GwVg2eodK8.jpg?AWSAccessKeyId=JO3ELGV4BGLFW7Y3EZXN&Expires=1719806400&Signature=%2FRbYE74gEUaJvURMA4hiYutX6Kg%3D',
#    'publishedAt': '2024-06-24T16:05:05Z',
#    'content': "TiberiusGracchus44:tricycleracer: He said the meat from the shark will be donated to the homeless; a gesture the company has been doing for years.\r\nAren't the homeless suffering enough as it is?\r\nI w… [+351 chars]"},
#   {'source': {'id': None, 'name': 'The New Yorker'},
#    'author': 'Jack Truesdale',
#    'title': 'How to Pick Stocks Like You’re in Congress',
#    'description': 'The team at Autopilot, an app that lets you copy the trades of Nancy Pelosi’s husband (up forty-five per cent last year) or Dan Crenshaw (up forty-one), choose their newest offering, Jack Truesdale writes.',
#    'url': 'https://www.newyorker.com/magazine/2024/06/03/how-to-pick-stocks-like-youre-in-congress',
#    'urlToImage': 'https://media.newyorker.com/photos/665110b013ca3a6fd7f5d313/16:9/w_1280,c_limit/r44339illuweb-site.png',
#    'publishedAt': '2024-05-27T10:00:00Z',
#    'content': 'The old adage about investing is that, unless you are, say, Warren Buffett, you cant beat the market. But thats not strictly true. Many members of Congress post excellent earnings. Consider Brian Hig… [+4656 chars]'},
#   {'source': {'id': None, 'name': 'Upenn.edu'},
#    'author': 'Victor Mair',
#    'title': 'It is that time of the year again',
#    'description': 'Florida 12-year-old Bruhat Soma wins 96th Scripps National Spelling Bee after competition’s second-ever spell-off By Sydney Bishop and Christina Maxouris, CNN (5/31/24) — Bruhat Soma, 12, of Florida won the 96th Scripps National Spelling Bee Thursday night af…',
#    'url': 'https://languagelog.ldc.upenn.edu/nll/?p=64360',
#    'urlToImage': None,
#    'publishedAt': '2024-06-04T00:37:32Z',
#    'content': '« previous post | \r\nFlorida 12-year-old Bruhat Soma wins 96th Scripps National Spelling Bee after competitions second-ever spell-off\r\nBy Sydney Bishop and Christina Maxouris, CNN (5/31/24)\r\n—\r\nBruhat… [+5852 chars]'},
#   {'source': {'id': None, 'name': 'Fark.com'},
#    'author': None,
#    'title': 'Given the choice of paying for his stolen beer or going to jail, Florida Man pops one open and picks the latter option [Florida]',
#    'description': 'Given the choice of paying for his stolen beer or going to jail, Florida Man pops one open and picks the latter option',
#    'url': 'https://www.fark.com/comments/13294174/Given-choice-of-paying-for-his-stolen-beer-going-to-jail-Florida-Man-pops-one-open-picks-latter-option',
#    'urlToImage': 'https://usrimg-full.fark.net/F/FT/fark_FTIRUXCMlgXArax23HufKjxo-ek.jpg?AWSAccessKeyId=JO3ELGV4BGLFW7Y3EZXN&Expires=1719201600&Signature=tX30xqOdccDIm6OmpvuzsP0zygM%3D',
#    'publishedAt': '2024-06-20T00:05:04Z',
#    'content': '<li>Links are submitted by members of the Fark community.\r\n</li><li>When community members submit a link, they also write a custom headline for the story.\r\n</li><li>Other Farkers comment on the links… [+177 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Nathaniel Popper',
#    'title': 'An inside look at the weekend the GameStop frenzy began on WallStreetBets',
#    'description': 'Journalist Nathaniel Popper recounts the inner workings of the subreddit WallStreetBets and how it spoke to a generation of lonely young men.',
#    'url': 'https://www.businessinsider.com/wallstreetbets-gamestop-nathaniel-popper-book-excerpt-2024-6',
#    'urlToImage': 'https://i.insider.com/6663676ced9a404d829bdbef?width=1200&format=jpeg',
#    'publishedAt': '2024-06-10T20:15:02Z',
#    'content': 'In a new book, writer Nathaniel Popper details the GameStop frenzy and how WallStreetBets became a cultural movement that upended the global financial markets.Nick Dolding/Getty, Gamestop, Tyler Le/B… [+17075 chars]'},
#   {'source': {'id': None, 'name': 'Fark.com'},
#    'author': None,
#    'title': 'Man arrested after going into unlocked bank and not stealing any money [Florida]',
#    'description': 'Man arrested after going into unlocked bank and not stealing any money',
#    'url': 'https://www.fark.com/comments/13296448/Man-arrested-after-going-into-unlocked-bank-not-stealing-any-money',
#    'urlToImage': 'https://usrimg-full.fark.net/C/Cp/fark_Cpv51YqdC7fsasVCWz06Sikx3v4.jpg?AWSAccessKeyId=JO3ELGV4BGLFW7Y3EZXN&Expires=1719201600&Signature=OeQ%2FDRViw1XuZRE7h3NOpt3VZ1Q%3D',
#    'publishedAt': '2024-06-21T16:49:46Z',
#    'content': "IDisME:Geotpf: I think a burglary charge is going to be really hard to get a conviction on.\r\nTrespassing is probably as good as you're going to get.\r\n+ B&amp;E, attempted burglary.\xa0 He wasn't opening… [+107 chars]"},
#   {'source': {'id': None, 'name': 'Deadline'},
#    'author': 'matthewgrobar',
#    'title': 'Jing Ai Ng’s Dark Comedy ‘Forge’ Adds Seven To Cast',
#    'description': 'The indie dark comedy Forge, currently shooting in Miami, has set its supporting cast. Newcomers include Edmund Donovan (Civil War), Eva De Dominici (The Cleaning Lady), Jack Falahee (How to Get Away with Murder), T. R. Knight (The Flight Attendant), Sonya Wa…',
#    'url': 'http://deadline.com/2024/05/jing-ai-ng-comedy-forge-adds-seven-to-cast-1235942464/',
#    'urlToImage': 'https://deadline.com/wp-content/uploads/2024/05/Edmund-Donovan-Eva-De-Dominici-Jack-Falahee-T.-R.-Knight-Sonya-Walger.jpg?w=1000',
#    'publishedAt': '2024-05-28T15:52:48Z',
#    'content': 'The indie dark comedy Forge, currently shooting in Miami, has set its supporting cast. \r\nNewcomers include Edmund Donovan (Civil War), Eva De Dominici (The Cleaning Lady), Jack Falahee (How to Get Aw… [+1645 chars]'},
#   {'source': {'id': None, 'name': 'Fark.com'},
#    'author': None,
#    'title': 'Stonks, music history, geography, and Florida Man are all on the Fark Weird News Quiz, May 30 - June 5 D-Day Edition [Weird]',
#    'description': 'Stonks, music history, geography, and Florida Man are all on the Fark Weird News Quiz, May 30 - June 5 D-Day Edition',
#    'url': 'https://www.fark.com/comments/13281220/Stonks-music-history-geography-Florida-Man-are-all-on-Fark-Weird-News-Quiz-May-30-June-5-D-Day-Edition',
#    'urlToImage': 'https://img.fark.net/images/2013/site/farkLogo2Big.gif',
#    'publishedAt': '2024-06-08T00:49:47Z',
#    'content': 'One of the stories I ran across yesterday was that of Bill Millin, who landed with UK troops on Sword Beach armed only with a knife - that he never used. See, his commanding officer was Brigadier Sim… [+2421 chars]'},
#   {'source': {'id': None, 'name': 'The Daily Dot'},
#    'author': 'Lindsey Weedston',
#    'title': 'The legacy of Chester Stone, Florida man and internet sensation',
#    'description': 'Chester Stone is an internet personality who gained fame with low-quality comedy videos in which he tells stories, acts wacky with his friends, and repeats his catchphrase “god motherf—ing damn!” He started on Instagram and has since spread his act over to Ti…',
#    'url': 'https://www.dailydot.com/memes/chester-stone/',
#    'urlToImage': 'https://uploads.dailydot.com/2024/06/chester-stone.jpg?auto=compress&fm=pjpg',
#    'publishedAt': '2024-06-07T20:48:28Z',
#    'content': 'Chester Stone is an internet personality who gained fame with low-quality comedy videos in which he tells stories, acts wacky with his friends, and repeats his catchphrase god motherfing damn! He sta… [+4628 chars]'},
#   {'source': {'id': None, 'name': 'Orlando Sentinel'},
#    'author': 'Martin E. Comas, Orlando Sentinel',
#    'title': 'Florida homeless men sue Seminole for criminalizing panhandling',
#    'description': 'Carl Faustin is a homeless and disabled man who’s made his living for years by holding signs at busy intersections in Seminole County asking for money, food ...',
#    'url': 'https://www.orlandosentinel.com/2024/06/10/homeless-men-sue-seminole-for-criminalizing-panhandling/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/e0WnGkmgUGnS2ZKh.HVVNQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD05MDA-/https://media.zenfs.com/en/orlando_sentinel_national_858/5c8a61b3e879cf79cde434fb7de633d1',
#    'publishedAt': '2024-06-10T14:56:00Z',
#    'content': 'Carl Faustin is a homeless and disabled man whos made his living for years by holding signs at busy intersections in Seminole County asking for money, food or help from passers-by.\r\nBut in court docu… [+5281 chars]'},
#   {'source': {'id': None, 'name': 'Every.to'},
#    'author': 'Gareth Edwards',
#    'title': 'The Misfit Who Built the IBM PC',
#    'description': "Don Estridge broke all of Big Blue's rules to create the home computer. The company would never forgive him for it.",
#    'url': 'https://every.to/the-crazy-ones/the-misfit-who-built-the-ibm-pc',
#    'urlToImage': 'https://d24ovhgu8s7341.cloudfront.net/uploads/post/social_media_image/3119/Screenshot_2024-06-05_at_10.04.46_AM.png',
#    'publishedAt': '2024-06-06T10:55:32Z',
#    'content': 'Sponsored by: Every\r\nWork with the Every team to bring AI to your organization\r\nWe launched our consulting arm because we were constantly hearing from readers that while they wanted to implement AI t… [+50336 chars]'},
#   {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#    'author': 'Paul Kasabian',
#    'title': "John Calipari Talks New Roster 'Formula' at Arkansas, Lessons Learned from Kentucky",
#    'description': "Arkansas men's basketball head coach John Calipari routinely brought in the top freshmen classes in the country during his time at Kentucky (2009-2024), but…",
#    'url': 'https://bleacherreport.com/articles/10122980-john-calipari-talks-new-roster-formula-at-arkansas-lessons-learned-from-kentucky',
#    'urlToImage': 'https://media.bleacherreport.com/image/upload/c_fill,g_faces,w_3800,h_2000,q_95/v1717028461/fpv7kqmw0jcwip7soz38.jpg',
#    'publishedAt': '2024-05-30T00:50:01Z',
#    'content': "Wesley Hitt/Getty Images\r\nArkansas men's basketball head coach John Calipari routinely brought in the top freshmen classes in the country during his time at Kentucky (2009-2024), but he admitted that… [+2042 chars]"},
#   {'source': {'id': None, 'name': 'Reason'},
#    'author': 'C.J. Ciaramella',
#    'title': "A Florida Man Was Arrested for Filming Marion County Sheriff's Deputies. Now He's Suing.",
#    'description': 'Numerous federal appeals courts have ruled that filming police is protected under the First Amendment, but police continue to illegally arrest people for it.',
#    'url': 'https://reason.com/2024/06/19/a-florida-man-was-arrested-for-filming-marion-county-sheriffs-deputies-now-hes-suing/',
#    'urlToImage': 'https://d2eehagpk5cl65.cloudfront.net/img/q60/uploads/2024/06/nathansen-arrest.jpg',
#    'publishedAt': '2024-06-19T15:15:43Z',
#    'content': "A Florida man has filed a federal civil rights lawsuit three years after a Marion County sheriff's deputy arrested him for filming officers from a public sidewalk. In 2021, Marion County Sheriff's De… [+3587 chars]"},
#   {'source': {'id': None, 'name': 'Instapundit.com'},
#    'author': 'Stephen Green',
#    'title': 'FLORIDA, MAN: Florida ranked top of list for startup activity, economic health. “For its findings, W',
#    'description': 'FLORIDA, MAN: Florida ranked top of list for startup activity, economic health. “For its findings, WalletHub reviewed 28 key indicators of economic performance and strength across all 50 states and the District of Columbia. The study specifically looked at da…',
#    'url': 'https://instapundit.com/651891/',
#    'urlToImage': 'https://instapundit.com/wp-content/themes/instapundit/images/opengraph-default.png',
#    'publishedAt': '2024-06-06T19:51:49Z',
#    'content': 'FLORIDA, MAN: Florida ranked top of list for startup activity, economic health. “For its findings, WalletHub reviewed 28 key indicators of economic performance and strength across all 50 states and t… [+179 chars]'},
#   {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#    'author': 'Jack Murray',
#    'title': 'College Baseball Super Regionals 2024: Results, Highlights and Bracket from Friday',
#    'description': 'The regionals have come and gone and 16 baseball programs are still in the hunt for a national championship. Friday was the start of the super regional round,…',
#    'url': 'https://bleacherreport.com/articles/10124007-college-baseball-super-regionals-2024-results-highlights-and-bracket-from-friday',
#    'urlToImage': 'https://media.bleacherreport.com/image/upload/c_fill,g_faces,w_3800,h_2000,q_95/v1717803661/jubacvdnz1nydmzf2iry.jpg',
#    'publishedAt': '2024-06-08T01:58:27Z',
#    'content': 'Isaiah Vazquez/Getty Images\r\nThe regionals have come and gone and 16 baseball programs are still in the hunt for a national championship.\r\nFriday was the start of the super regional round, with the r… [+9374 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Will Yakowicz, Forbes Staff, \n Will Yakowicz, Forbes Staff\n https://www.forbes.com/sites/willyakowicz/',
#    'title': 'Honor Thy Father: The Saga Of A Drug Smuggler’s Son',
#    'description': 'Brady Cobb founded Sunburn Cannabis as a tribute to his dad, a legendary “saltwater cowboy” who once operated a $300 million ring smuggling Colombian weed into Florida.',
#    'url': 'https://www.forbes.com/sites/willyakowicz/2024/06/14/brady-cobb-interview-sunburn-cannabis-bill-cobb-operation-sunburn/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/666c68fb717953967dd2b533/0x0.jpg?format=jpg&crop=1920,1080,x0,y0,safe&height=900&width=1600&fit=bounds',
#    'publishedAt': '2024-06-16T10:00:00Z',
#    'content': 'Brady Cobb founded Sunburn Cannabis as a tribute to his dad, a legendary saltwater cowboy who once operated a $300 million ring smuggling Colombian weed into Florida. Bill Cobb was sentenced to 20 ye… [+12386 chars]'},
#   {'source': {'id': None, 'name': 'Daily Beast'},
#    'author': 'Graham Keeley',
#    'title': 'Nation Gripped by Mystery of Missing Florida Woman Who Went to Start New Life Overseas',
#    'description': "Photo Illustration by Erin O'Flynn/The Daily Beast/United States District Court Southern District of Florida and Getty Images\r\nMADRID—Like a hunt for a needle in a haystack, FBI officers in blue and yellow jackets and Spanish police painstakingly searched thr…",
#    'url': 'https://www.thedailybeast.com/ana-maria-knezevich-spain-gripped-by-mystery-of-missing-florida-woman',
#    'urlToImage': 'https://img.thedailybeast.com/image/upload/c_crop,d_placeholder_euli9k,h_1688,w_3000,x_0,y_0/dpr_2.0/c_limit,w_740/fl_lossy,q_auto/v1717875190/240608-missing-florida-woman-hero_yfzhgq',
#    'publishedAt': '2024-06-09T03:14:47Z',
#    'content': 'MADRIDLike a hunt for a needle in a haystack, FBI officers in blue and yellow jackets and Spanish police painstakingly searched through the countryside outside Madrid for the body of Ana María Henao … [+5474 chars]'},
#   {'source': {'id': 't3n', 'name': 'T3n'},
#    'author': 'Ann-Catherin Karg',
#    'title': 'Wie dieser Satellit die Wettervorhersagen deutlich verbessern soll',
#    'description': 'Wenn am 25. Juni eine Falcon-Heavy-Rakete in den Weltraum startet, hat sie eine besondere Fracht an Bord. Der Satellit Goes-U soll das Zeug dazu haben, Wettervorhersagen auf ein neues Level zu heben. Die National Oceanic and Atmospheric Administration (NOAA) …',
#    'url': 'https://t3n.de/news/wie-dieser-satellit-die-wettervorhersagen-deutlich-verbessern-soll-1632100/',
#    'urlToImage': 'https://t3n.de/news/wp-content/uploads/2024/06/GEOS-U.jpg',
#    'publishedAt': '2024-06-24T10:00:13Z',
#    'content': 'Die National Oceanic and Atmospheric Administration (NOAA) beliefert Wissenschaftler:innen bereits seit 1975 mit Daten aus dem All. Doch der neueste Coup der NOAA wird von Meteorolog:innen auf der ga… [+2925 chars]'}]}
