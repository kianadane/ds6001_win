# %% [markdown]
# # Lab Assignment 4: Using APIs in Python
# ## DS 6001: Practice and Application of Data Science
#
# ### Instructions
# Please answer the following questions as completely as possible using text, code, and the results of code as needed. Format your answers in a Jupyter notebook. To receive full credit, make sure you address every part of the problem, and make sure your document is formatted in a clean and professional way.

# %% [markdown]
# In this lab, you will work with the public API provided by [genius.com](https://genius.com/), a website that calls itself "the world’s biggest collection of song lyrics and musical knowledge." You will need to read the API documentation carefully, acquire an access key, and use it without sharing it to pull data from this API into Python. You will also practice using a library made specifically to wrap around `requests` to make calling from the Genius API easier.
#
# ## Problem 0
# Import the following libraries:

# %%
import numpy as np
import pandas as pd
import requests
import json
import os
from dotenv import load_dotenv
import sys
sys.tracebacklimit = 0 # turn off the error tracebacks

# %% [markdown]
# ## Problem 1
# The Genius API documentation is here: https://docs.genius.com/#/getting-started-h1. Read through the documentation carefully. Although the Genius API is free and public, it still requires users an access key to use the API. In this case, Genius provides users with three codes: a client ID, a client ID secret, and a client access token. Use the documentation to find a way to obtain these codes for yourself. Write a paragraph that describes all of the steps you needed to take (but DO NOT list your access codes in this paragraph).
# [4 points]

# %% [markdown]
# ## Problem 1 answer

# %% [markdown]
# ##### - To get the three codes that Genius provides users to use their API, I first navigated to the <u>API Client management page</u> from the link provided in Problem 1.
#
# ##### - Next, I used the School of Data Science website for <b>app webiste URL</b> with "song lyrics project" for <b>App name.</b>
#
# ##### - Upon submitting the form, my screen showed three fields containing the three codes I need to use the API in my IDE.

# %% [markdown]
# ## Problem 2
# Create a `.env` file for this project. Open it, copy your access codes into it, and save it. Then use Python code to load the environmental variables contained in the `.env` file, and create variables that contain each of the three codes. (You can print these variables to make sure it worked, but do not allow your access keys to display in your notebook). [4 points]

# %%
load_dotenv('.env')
genius_client_access_token = os.getenv('genius_client_access_token')
client_id = os.getenv('genius_client_id')
client_secret = os.getenv('geniuskey')

# %% [markdown]
# ## Problem 3
# The root for all Genius APIs is https://api.genius.com. Find the endpoint for the Search API. (You will have to click the "Authorize with Genius" button in the upper-right corner if you haven't already done so). Use the `requests` library to issue a search for Bob Dylan. Genius's API is organized in a way that every individual artist has his or her own API endpoint. Display a portion of the JSON output that displays the API endpoint path for the data on Bob Dylan.
#
# Hint: to authenticate, specify your access token (not your client ID or client secret) as the `access_token` parameter. You will have to dig around the JSON output to find the artist ID, but it is listed under `primary_artist` several branches down the JSON tree. [4 points]

# %%
root = 'https://api.genius.com'
endpoint = '/search'
headers = {'Authorization': 'Bearer ' + genius_client_access_token}
params = {'q': 'Bob Dylan'}

r = requests.get(root + endpoint, params=params, headers=headers)

# %%
bobby = json.loads(r.text)
bobby['response']['hits'][0]['result']
# Out:
# {'annotation_count': 12,
#  'api_path': '/songs/79424',
#  'artist_names': 'Bob Dylan',
#  'full_title': "Blowin' in the Wind by\xa0Bob\xa0Dylan",
#  'header_image_thumbnail_url': 'https://images.genius.com/84e1705bc644951972168d1015fa9024.300x300x1.jpg',
#  'header_image_url': 'https://images.genius.com/84e1705bc644951972168d1015fa9024.1000x1000x1.jpg',
#  'id': 79424,
#  'lyrics_owner_id': 73267,
#  'lyrics_state': 'complete',
#  'path': '/Bob-dylan-blowin-in-the-wind-lyrics',
#  'primary_artist_names': 'Bob Dylan',
#  'pyongs_count': 48,
#  'relationships_index_url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-sample',
#  'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#  'release_date_for_display': 'May 27, 1963',
#  'release_date_with_abbreviated_month_for_display': 'May. 27, 1963',
#  'song_art_image_thumbnail_url': 'https://images.genius.com/84e1705bc644951972168d1015fa9024.300x300x1.jpg',
#  'song_art_image_url': 'https://images.genius.com/84e1705bc644951972168d1015fa9024.1000x1000x1.jpg',
#  'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 607178},
#  'title': 'Blowin’ in the Wind',
#  'title_with_featured': "Blowin' in the Wind",
#  'url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-lyrics',
#  'featured_artists': [],
#  'primary_artist': {'api_path': '/artists/181',
#   'header_image_url': 'https://images.genius.com/e87fb11dd7f33cc7fd1a8915ad36f7c9.1000x667x1.png',
#   'id': 181,
#   'image_url': 'https://images.genius.com/571780cc8959528e8166e5894ab13d6f.1000x1000x1.jpg',
#   'is_meme_verified': False,
#   'is_verified': False,
#   'name': 'Bob Dylan',
#   'url': 'https://genius.com/artists/Bob-dylan'},
#  'primary_artists': [{'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/e87fb11dd7f33cc7fd1a8915ad36f7c9.1000x667x1.png',
#    'id': 181,
#    'image_url': 'https://images.genius.com/571780cc8959528e8166e5894ab13d6f.1000x1000x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'}]}

# %% [markdown]
# ## Problem 4
# Add `/songs` to the end of the the endpoint path you found in problem 3 and use this path to request the 20 most popular Bob Dylan songs. Organize these data in a `pandas` data frame. [4 points]

# %%
root = 'https://api.genius.com'
endpoint2 = '/artists/181/songs'
headers = {'Authorization': 'Bearer ' + genius_client_access_token}
params = {'sort': 'popularity', 'per_page': 20}

r = requests.get(root + endpoint2, params=params, headers=headers)

# %%
bob_songs = json.loads(r.text)
bob_songs = pd.DataFrame(bob_songs)

# %%
artist = genius.search_artist("Bob Dylan", max_songs=13, sort="popularity")

# %%
root = 'https://api.genius.com'
endpoint = '/artists/181/songs'
headers = {'Authorization': 'Bearer ' + genius_client_access_token}


r = requests.get(root + endpoint, headers=headers)

# %%
import requests

root = 'https://api.genius.com'
endpoint = '/artists/181/songs'
headers = {'Authorization': 'Bearer ' + genius_client_access_token}
params = {'sort' : 'popularity', 'per_page' : 20, 'page' : 1}
r_songs = requests.get(root + endpoint, headers=headers, params = params)

# %%
songs_df = pd.json_normalize(json.loads(r_songs.text), record_path=['response', 'songs'])
songs_df
# Out:
#     annotation_count        api_path                     artist_names  \
# 0                 15    /songs/96286                   USA For Africa
# 1                 12    /songs/79424                        Bob Dylan
# 2                  1    /songs/68146                            Adele
# 3                 18    /songs/62605                        Bob Dylan
# 4                128  /songs/5393247                        Bob Dylan
# 5                  7   /songs/103982  Guns N' Roses (Ft. ​The Waters)
# 6                 15    /songs/98664                        Bob Dylan
# 7                 28    /songs/54784                        Bob Dylan
# 8                 10    /songs/84846                        Bob Dylan
# 9                 10    /songs/63341      The Jimi Hendrix Experience
# 10                30    /songs/87402                        Bob Dylan
# 11                10    /songs/79749                        Bob Dylan
# 12                20      /songs/224                        Bob Dylan
# 13                36   /songs/105186                        Bob Dylan
# 14                22    /songs/75446                        Bob Dylan
# 15                14   /songs/154239                    Darius Rucker
# 16                34   /songs/118799                        Bob Dylan
# 17                79    /songs/92350                        Bob Dylan
# 18                 6   /songs/199531                        Bob Dylan
# 19                51    /songs/75463                        Bob Dylan
#
#                                            full_title  \
# 0                  We Are the World by USA For Africa
# 1                    Blowin' in the Wind by Bob Dylan
# 2                      Make You Feel My Love by Adele
# 3          The Times They Are A-Changin' by Bob Dylan
# 4                       Murder Most Foul by Bob Dylan
# 5   Knockin’ on Heaven’s Door by Guns N' Roses (Ft...
# 6               All Along the Watchtower by Bob Dylan
# 7                   Like a Rolling Stone by Bob Dylan
# 8      Don't Think Twice, It's All Right by Bob Dylan
# 9   All Along the Watchtower by The Jimi Hendrix E...
# 10                             Hurricane by Bob Dylan
# 11                 Make You Feel My Love by Bob Dylan
# 12           Subterranean Homesick Blues by Bob Dylan
# 13            A Hard Rain's A-Gonna Fall by Bob Dylan
# 14                    Mr. Tambourine Man by Bob Dylan
# 15                       Wagon Wheel by Darius Rucker
# 16                    Tangled Up in Blue by Bob Dylan
# 17                        Desolation Row by Bob Dylan
# 18             Knockin’ on Heaven’s Door by Bob Dylan
# 19  It's Alright, Ma (I'm Only Bleeding) by Bob Dylan
#
#                            header_image_thumbnail_url  \
# 0   https://images.genius.com/c21fb053cb43a6a35e31...
# 1   https://images.genius.com/84e1705bc64495197216...
# 2   https://images.genius.com/becead7e44b8202463f0...
# 3   https://images.genius.com/e00b4dcec135cb5ab3ee...
# 4   https://images.genius.com/7fbaf838ffdf99315408...
# 5   https://images.genius.com/cb2614550098bf753ab3...
# 6   https://images.genius.com/f727dfc7b28942c59cd6...
# 7   https://images.genius.com/5de9704b9bd8773ddbcb...
# 8   https://images.genius.com/84e1705bc64495197216...
# 9   https://images.genius.com/892e94dacb1ac51070e5...
# 10  https://images.genius.com/2ae7853a0fc26b8340ce...
# 11  https://images.genius.com/cd0a26733cc459710d09...
# 12  https://images.genius.com/e4013e376bc0912bdb9b...
# 13  https://images.genius.com/84e1705bc64495197216...
# 14  https://images.genius.com/e4013e376bc0912bdb9b...
# 15  https://images.genius.com/71f204d1ae373a8a004a...
# 16  https://images.genius.com/9146ba54ed06288f10b2...
# 17  https://images.genius.com/b67cf8e6822a6ec84ea9...
# 18  https://images.rapgenius.com/328b31b5fe67895fa...
# 19  https://images.genius.com/e4013e376bc0912bdb9b...
#
#                                      header_image_url       id  \
# 0   https://images.genius.com/c21fb053cb43a6a35e31...    96286
# 1   https://images.genius.com/84e1705bc64495197216...    79424
# 2   https://images.genius.com/becead7e44b8202463f0...    68146
# 3   https://images.genius.com/e00b4dcec135cb5ab3ee...    62605
# 4   https://images.genius.com/7fbaf838ffdf99315408...  5393247
# 5   https://images.genius.com/cb2614550098bf753ab3...   103982
# 6   https://images.genius.com/f727dfc7b28942c59cd6...    98664
# 7   https://images.genius.com/5de9704b9bd8773ddbcb...    54784
# 8   https://images.genius.com/84e1705bc64495197216...    84846
# 9   https://images.genius.com/892e94dacb1ac51070e5...    63341
# 10  https://images.genius.com/2ae7853a0fc26b8340ce...    87402
# 11  https://images.genius.com/cd0a26733cc459710d09...    79749
# 12  https://images.genius.com/e4013e376bc0912bdb9b...      224
# 13  https://images.genius.com/84e1705bc64495197216...   105186
# 14  https://images.genius.com/e4013e376bc0912bdb9b...    75446
# 15  https://images.genius.com/71f204d1ae373a8a004a...   154239
# 16  https://images.genius.com/9146ba54ed06288f10b2...   118799
# 17  https://images.genius.com/b67cf8e6822a6ec84ea9...    92350
# 18  https://images.rapgenius.com/328b31b5fe67895fa...   199531
# 19  https://images.genius.com/e4013e376bc0912bdb9b...    75463
#
#     lyrics_owner_id lyrics_state  \
# 0           4733728     complete
# 1             73267     complete
# 2             82481     complete
# 3             49202     complete
# 4           3360167     complete
# 5            168784     complete
# 6               779     complete
# 7                 7     complete
# 8            125524     complete
# 9             31298     complete
# 10           132320     complete
# 11             5307     complete
# 12                4     complete
# 13               16     complete
# 14            74226     complete
# 15            10380     complete
# 16             1850     complete
# 17           145715     complete
# 18           225680     complete
# 19            74226     complete
#
#                                                  path  ... stats.pageviews  \
# 0             /Usa-for-africa-we-are-the-world-lyrics  ...          656113
# 1                /Bob-dylan-blowin-in-the-wind-lyrics  ...          607184
# 2                 /Adele-make-you-feel-my-love-lyrics  ...          594506
# 3      /Bob-dylan-the-times-they-are-a-changin-lyrics  ...          527408
# 4                  /Bob-dylan-murder-most-foul-lyrics  ...          505795
# 5        /Guns-n-roses-knockin-on-heavens-door-lyrics  ...          502909
# 6          /Bob-dylan-all-along-the-watchtower-lyrics  ...          497349
# 7              /Bob-dylan-like-a-rolling-stone-lyrics  ...          465338
# 8    /Bob-dylan-dont-think-twice-its-all-right-lyrics  ...          422189
# 9   /The-jimi-hendrix-experience-all-along-the-wat...  ...          389069
# 10                        /Bob-dylan-hurricane-lyrics  ...          382918
# 11            /Bob-dylan-make-you-feel-my-love-lyrics  ...          369985
# 12      /Bob-dylan-subterranean-homesick-blues-lyrics  ...          325555
# 13        /Bob-dylan-a-hard-rains-a-gonna-fall-lyrics  ...          299788
# 14                /Bob-dylan-mr-tambourine-man-lyrics  ...          282227
# 15                  /Darius-rucker-wagon-wheel-lyrics  ...          274652
# 16               /Bob-dylan-tangled-up-in-blue-lyrics  ...          216298
# 17                   /Bob-dylan-desolation-row-lyrics  ...          214711
# 18          /Bob-dylan-knockin-on-heavens-door-lyrics  ...          206274
# 19  /Bob-dylan-its-alright-ma-im-only-bleeding-lyrics  ...          205827
#
#     primary_artist.api_path  \
# 0           /artists/370890
# 1              /artists/181
# 2             /artists/2300
# 3              /artists/181
# 4              /artists/181
# 5              /artists/637
# 6              /artists/181
# 7              /artists/181
# 8              /artists/181
# 9           /artists/634985
# 10             /artists/181
# 11             /artists/181
# 12             /artists/181
# 13             /artists/181
# 14             /artists/181
# 15           /artists/21867
# 16             /artists/181
# 17             /artists/181
# 18             /artists/181
# 19             /artists/181
#
#                       primary_artist.header_image_url primary_artist.id  \
# 0   https://images.genius.com/3fb2d9f68c911b547339...            370890
# 1   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 2   https://images.genius.com/87aa5d8c32965a10e0e7...              2300
# 3   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 4   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 5   https://images.genius.com/83c4b54659d674bd3778...               637
# 6   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 7   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 8   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 9   https://images.genius.com/2631895179875ea7541b...            634985
# 10  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 11  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 12  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 13  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 14  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 15  https://images.genius.com/6a629cf1a4b6fec5b21a...             21867
# 16  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 17  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 18  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 19  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
#
#                              primary_artist.image_url  \
# 0   https://images.genius.com/3fb2d9f68c911b547339...
# 1   https://images.genius.com/571780cc8959528e8166...
# 2   https://images.genius.com/8a23ab928ccfce13accf...
# 3   https://images.genius.com/571780cc8959528e8166...
# 4   https://images.genius.com/571780cc8959528e8166...
# 5   https://images.genius.com/53ddc7640957b4279d9c...
# 6   https://images.genius.com/571780cc8959528e8166...
# 7   https://images.genius.com/571780cc8959528e8166...
# 8   https://images.genius.com/571780cc8959528e8166...
# 9   https://images.genius.com/ca64447350d06d6dc144...
# 10  https://images.genius.com/571780cc8959528e8166...
# 11  https://images.genius.com/571780cc8959528e8166...
# 12  https://images.genius.com/571780cc8959528e8166...
# 13  https://images.genius.com/571780cc8959528e8166...
# 14  https://images.genius.com/571780cc8959528e8166...
# 15  https://images.genius.com/6009b412250fcc9da909...
# 16  https://images.genius.com/571780cc8959528e8166...
# 17  https://images.genius.com/571780cc8959528e8166...
# 18  https://images.genius.com/571780cc8959528e8166...
# 19  https://images.genius.com/571780cc8959528e8166...
#
#    primary_artist.is_meme_verified primary_artist.is_verified  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# 5                            False                      False
# 6                            False                      False
# 7                            False                      False
# 8                            False                      False
# 9                            False                      False
# 10                           False                      False
# 11                           False                      False
# 12                           False                      False
# 13                           False                      False
# 14                           False                      False
# 15                           False                      False
# 16                           False                      False
# 17                           False                      False
# 18                           False                      False
# 19                           False                      False
#
#             primary_artist.name  \
# 0                USA For Africa
# 1                     Bob Dylan
# 2                         Adele
# 3                     Bob Dylan
# 4                     Bob Dylan
# 5                 Guns N’ Roses
# 6                     Bob Dylan
# 7                     Bob Dylan
# 8                     Bob Dylan
# 9   The Jimi Hendrix Experience
# 10                    Bob Dylan
# 11                    Bob Dylan
# 12                    Bob Dylan
# 13                    Bob Dylan
# 14                    Bob Dylan
# 15                Darius Rucker
# 16                    Bob Dylan
# 17                    Bob Dylan
# 18                    Bob Dylan
# 19                    Bob Dylan
#
#                                    primary_artist.url stats.concurrents
# 0           https://genius.com/artists/Usa-for-africa               NaN
# 1                https://genius.com/artists/Bob-dylan               NaN
# 2                    https://genius.com/artists/Adele               2.0
# 3                https://genius.com/artists/Bob-dylan               NaN
# 4                https://genius.com/artists/Bob-dylan               NaN
# 5             https://genius.com/artists/Guns-n-roses               NaN
# 6                https://genius.com/artists/Bob-dylan               NaN
# 7                https://genius.com/artists/Bob-dylan               NaN
# 8                https://genius.com/artists/Bob-dylan               NaN
# 9   https://genius.com/artists/The-jimi-hendrix-ex...               NaN
# 10               https://genius.com/artists/Bob-dylan               NaN
# 11               https://genius.com/artists/Bob-dylan               NaN
# 12               https://genius.com/artists/Bob-dylan               NaN
# 13               https://genius.com/artists/Bob-dylan               NaN
# 14               https://genius.com/artists/Bob-dylan               NaN
# 15           https://genius.com/artists/Darius-rucker               NaN
# 16               https://genius.com/artists/Bob-dylan               NaN
# 17               https://genius.com/artists/Bob-dylan               NaN
# 18               https://genius.com/artists/Bob-dylan               NaN
# 19               https://genius.com/artists/Bob-dylan               NaN
#
# [20 rows x 37 columns]

# %% [markdown]
# ## Problem 5
# Install and import the `lyricsgenius` library in Python, which is a wrapper around `requests` that works specifically with the Genius API. . Follow the guide on the GitHub repository for this library (https://github.com/johnwmillr/LyricsGenius) for instructions on using the library. Use the `lyricsgenius` library to download and display the lyrics to "Tangled Up in Blue" by Bob Dylan. [4 points]

# %%
import lyricsgenius
genius = lyricsgenius.Genius(genius_client_access_token)

# %%
artist = genius.search_artist("Bob Dylan", max_songs=13, sort="popularity")
# Out:
# Searching for songs by Bob Dylan...
#
# Song 1: "Blowin’ in the Wind"
# Song 2: "The Times They Are A-Changin’"
# Song 3: "Murder Most Foul"
# Song 4: "All Along the Watchtower"
# Song 5: "Like a Rolling Stone"
# Song 6: "Don’t Think Twice, It’s All Right"
# Song 7: "Hurricane"
# Song 8: "Make You Feel My Love"
# Song 9: "Subterranean Homesick Blues"
# Song 10: "A Hard Rain’s A-Gonna Fall"
# Song 11: "Mr. Tambourine Man"
# Song 12: "Tangled Up in Blue"
# Song 13: "Desolation Row"
#
# Reached user-specified song limit (13).
# Done. Found 13 songs.

# %%
song = artist.song("Tangled up in Blue")
print(song.lyrics)
# Out:
# Searching for "Tangled up in Blue" by Bob Dylan...
# Done.
# 97 ContributorsTangled Up in Blue Lyrics[Verse 1]
# Early one morning the sun was shining
# I was laying in bed
# Wondering if she'd changed at all
# If her hair was still red
# Her folks they said our lives together
# Sure was going to be rough
# They never did like Mama's homemade dress
# Papa's bankbook wasn't big enough
# And I was standing on the side of the road
# Rain falling on my shoes
# Heading out for the East Coast
# Lord knows I've paid some dues
# Getting through
# Tangled up in blue
#
# [Verse 2]
# She was married when we first met
# Soon to be divorced
# I helped her out of a jam, I guess
# But I used a little too much force
# We drove that car as far as we could
# Abandoned it out west
# Split up on a dark sad night
# Both agreeing it was best
# She turned around to look at me
# As I was walking away
# I heard her say over my shoulder
# "We'll meet again someday
# On the avenue"
# Tangled up in blue
# See Bob Dylan LiveGet tickets as low as $14You might also like[Verse 3]
# I had a job in the great north woods
# Working as a cook for a spell
# But I never did like it all that much
# And one day the ax just fell
# So I drifted down to New Orleans
# Where I lucky was to be employed
# Working for a while on a fishing boat
# Right outside of Delacroix
# But all the while I was alone
# The past was close behind
# I seen a lot of women
# But she never escaped my mind
# And I just grew
# Tangled up in blue
#
# [Verse 4]
# She was working in a topless place
# And I stopped in for a beer
# I just kept looking at the side of her face
# In the spotlight, so clear
# And later on, when the crowd thinned out
# I was just about to do the same
# She was standing there, in back of my chair
# Said, "Tell me, don't I know your name?"
# I muttered something underneath my breath
# She studied the lines on my face
# I must admit, I felt a little uneasy
# When she bent down to tie the laces
# Of my shoe
# Tangled up in blue
# [Verse 5]
# She lit a burner on the stove
# And offered me a pipe
# "I thought you'd never say hello," she said
# "You look like the silent type"
# Then she opened up a book of poems
# And handed it to me
# Written by an Italian poet
# From the thirteenth century
# And every one of them words rang true
# And glowed like burning coal
# Pouring off of every page
# Like it was written in my soul
# From me to you
# Tangled up in blue
#
# [Verse 6]
# I lived with them on Montague Street
# In a basement down the stairs
# There was music in the cafes at night
# And revolution in the air
# Then he started into dealing with slaves
# And something inside of him died
# She had to sell everything she owned
# And froze up inside
# And when it finally, the bottom fell out
# I became withdrawn
# The only thing I knew how to do
# Was to keep on keeping on
# Like a bird that flew
# Tangled up in blue
# [Verse 7]
# So now I'm going back again
# I got to get to her somehow
# All the people we used to know
# They're an illusion to me now
# Some are mathematicians
# Some are carpenter's wives
# Don't know how it all got started
# I don't know what they're doing with their lives
# But me, I'm still on the road
# A-heading for another joint
# We always did feel the same
# We just saw it from a different point
# Of view
# Tangled up in blue26Embed
